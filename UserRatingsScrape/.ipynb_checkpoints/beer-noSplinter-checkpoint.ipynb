# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re

# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path)

# %%
# function for ratings scrape

def user_ratings(username):
    ratings_count = 0
    user_ratings = []
    avail_results = True 
    while avail_results:
        # assemble the url, make the request, isolate table
        url = f"https://www.beeradvocate.com/user/beers/?start={ratings_count}&ba={username}&order=dateD&view=R"
        html = requests.get(url)
        print(html.url)
        soup = BeautifulSoup(html.text, 'html.parser')
         # number of user ratings 
        ######need to dump the ratings from user scrape
        
        results = soup.find_all('table')
        

        #increase ratings count to get next page
        ratings_count += 50
        
        #get correct table rows
        ratings_list = results[0].find_all('tr')[3:] #increase ratings count to get next page
        
        #####need catch for no user ratings
        if len(ratings_list) > 0:
        
            #loop through and sort info
            for tr in ratings_list:
                tds = tr.find_all('td')

                # isolate some info
                user_rating = tds[-2].text
#                 abv = tds[-3].text
                rDev = re.findall(r"([\d.]*\d+)", tds[-1].text)[0]
                # further isolate element in list holding 3 features
                add_beer_info = tds[2].find_all('a')
                
                # extract info
#                 beer_name = add_beer_info[0].text
                beer_link_total = add_beer_info[0]['href']
                base_url_ba = "https://www.beeradvocate.com"
                beer_link = base_url_ba + beer_link_total[0:beer_link_total.find("?")]
#                 beer_style = add_beer_info[2].text
#                 brewery = add_beer_info[1].text

                #dump into dict
                ratings_dict = {
#                     "beer_name": beer_name,
#                     "brewery": brewery,
#                     "beer_style": beer_style,
#                     "beer_style_match": re.sub(r'\W+', '', beer_style.lower()),
                    "beer_link": beer_link,
                    "user_rating": user_rating,
#                     "abv": abv,
                    "rDev": rDev

                }

                # append link to list
                user_ratings.append(ratings_dict)
        else: 
            
            avail_results = False
    user_ratings_df = pd.DataFrame(user_ratings).drop_duplicates()
    
    return user_ratings_df

# %%
user_ratings_df = user_ratings('brutaltruth')
# Out:
# https://www.beeradvocate.com/user/beers/?start=0&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=50&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=100&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=150&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=200&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=250&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=300&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=350&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=400&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=450&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=500&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=550&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=600&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=650&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=700&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=750&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=800&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=850&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=900&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=950&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1000&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1050&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1100&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1150&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1200&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1250&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1300&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1350&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1400&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1450&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1500&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1550&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1600&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1650&ba=brutaltruth&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1700&ba=brutaltruth&order=dateD&view=R

# %%
beerFeatures_df = pd.read_csv("../StyleLinkScrape&Results/styleFeaturesComplete.csv")
beerFeatures_df
# Out:
#     Color  Flavor  Hoppiness  Maltiness  Fruitiness  Body  Sweetness  \
# 0    pale       1          0          0           0     1          0
# 1    gold       2          2          2           0     1          0
# 2    pale       2          2          0           0     2          0
# 3    gold       2          3          2           0     2          0
# 4   amber       2          0          2           0     2          0
# 5   amber       2          1          0           0     3          0
# 6   black       1          0          1           0     2          1
# 7   amber       2          2          2           0     2          2
# 8   amber       3          1          3           0     2          2
# 9   dark        3          0          2           0     3          0
# 10   gold       2          0          2           3     2          0
# 11   gold       2          2          0           0     2          0
# 12  dark        2          2          2           0     2          0
# 13  dark        2          1          2           0     3          2
# 14  amber       2          2          2           1     2          0
# 15  amber       2          2          2           0     2          0
# 16   gold       2          1          1           1     1          0
# 17   gold       2          2          0           2     1          0
# 18   gold       2          2          2           2     2          0
# 19  amber       2          3          2           0     2          0
# 20  amber       3          3          3           0     2          0
# 21   gold       2          2          2           0     2          0
# 22  dark        2          1          2           0     2          2
# 23  dark        1          2          0           0     2          1
# 24  dark        3          0          0           0     2          0
# 25  black       2          1          1           0     2          0
# 26  black       2          2          2           0     3          2
# 27  black       2          2          1           0     2          1
# 28  black       2          0          2           0     3          2
# 29  black       2          1          2           0     1          0
# 30   pale       2          2          1           0     2          1
# 31   gold       3          0          2           2     2          1
# 32   gold       2          1          3           1     1          2
# 33  amber       3          0          3           2     3          2
# 34  dark        3          1          2           2     2          0
# 35   gold       2          0          0           3     2          1
# 36   pale       2          1          1           1     2          0
# 37   pale       2          0          0           0     2          0
# 38   gold       2          0          0           2     2          0
# 39  amber       2          0          2           2     2          1
# 40   gold       2          1          0           2     2          0
# 41   gold       3          0          0           0     2          0
# 42  amber       2          1          1           3     2          2
# 43  amber       2          0          2           2     1          0
# 44   gold       2          0          0           3     2          0
# 45  amber       2          0          2           0     2          0
# 46  amber       2          1          2           0     2          2
# 47  dark        3          0          2           0     2          0
#
#    Custom Flavor  Sour    Aroma  spicy  bitter                     csv_name  \
# 0              0     0        0      0       0         americanadjunctlager
# 1              0     0        0      2       0            munichhelleslager
# 2              0     0   floral      0       2               germanpilsener
# 3              0     0   floral      0       2                czechpilsener
# 4              0     0  caramel      0       0        americanamberredlager
# 5        toasted     0        0      0       0                  oktoberfest
# 6              0     0        0      0       0                  schwarzbier
# 7              0     0        0      0       0                  viennalager
# 8        toasted     0        0      0       0                         bock
# 9      chocolate     0        0      0       0                   doppelbock
# 10             0     0        0      2       0                   weizenbock
# 11             0     0        0      0       0            maibockhellesbock
# 12             0     0        0      0       0             americanbrownale
# 13             0     0        0      0       0              englishbrownale
# 14       caramel     0        0      0       0          americanamberredale
# 15             0     0        0      0       0           americanpalealeapa
# 16             0     0    fruit      0       1            americanblondeale
# 17             0     0    fruit      0       2                englishbitter
# 18             0     0    fruit      0       0               englishpaleale
# 19        herbal     0        0      0       3                  americanipa
# 20             0     0        0      0       3    americandoubleimperialipa
# 21             0     0        0      0       0       englishindiapalealeipa
# 22         burnt     0        0      0       0               americanporter
# 23             0     0        0      0       2                englishporter
# 24       caramel     0        0      0       2                 balticporter
# 25       roasted     0        0      0       0                americanstout
# 26       roasted     0        0      0       0  americandoubleimperialstout
# 27       roasted     0        0      0       0                 oatmealstout
# 28             0     0        0      0       0               milksweetstout
# 29       roasted     0        0      0       2                irishdrystout
# 30       toasted     0        0      0       1               belgianpaleale
# 31       caramel     0    fruit      2       1                       dubbel
# 32             0     0        0      0       2                       tripel
# 33   brown sugar     0        0      0       1                quadrupelquad
# 34             0     0        0      2       0         belgianstrongdarkale
# 35        earthy     2    fruit      0       2           saisonfarmhouseale
# 36         wheat     0        0      0       2         americanpalewheatale
# 37         wheat     0        0      0       0                      witbier
# 38         wheat     2        0      0       0            berlinerweissbier
# 39        banana     0        0      0       1                 dunkelweizen
# 40             0     1        0      0       1                   hefeweizen
# 41             0     3        0      0       0              americanwildale
# 42             0     2        0      0       0                  lambicfruit
# 43             0     3        0      0       0               flandersredale
# 44             0     3        0      0       0                       gueuze
# 45       pumpkin     0        0      0       0                   pumpkinale
# 46             0     1        0      2       2                      ryebeer
# 47         smoke     0        0      0       0                   smokedbeer
#
#                           style_name                   match_name
# 0             American Adjunct Lager         americanadjunctlager
# 1                Munich Helles Lager            munichhelleslager
# 2                    German Pilsener               germanpilsener
# 3                     Czech Pilsener                czechpilsener
# 4         American Amber / Red Lager        americanamberredlager
# 5               Märzen / Oktoberfest            märzenoktoberfest
# 6                        Schwarzbier                  schwarzbier
# 7                       Vienna Lager                  viennalager
# 8                               Bock                         bock
# 9                         Doppelbock                   doppelbock
# 10                        Weizenbock                   weizenbock
# 11             Maibock / Helles Bock            maibockhellesbock
# 12                American Brown Ale             americanbrownale
# 13                 English Brown Ale              englishbrownale
# 14          American Amber / Red Ale          americanamberredale
# 15           American Pale Ale (APA)           americanpalealeapa
# 16               American Blonde Ale            americanblondeale
# 17                    English Bitter                englishbitter
# 18                  English Pale Ale               englishpaleale
# 19                      American IPA                  americanipa
# 20    American Double / Imperial IPA    americandoubleimperialipa
# 21      English India Pale Ale (IPA)       englishindiapalealeipa
# 22                   American Porter               americanporter
# 23                    English Porter                englishporter
# 24                     Baltic Porter                 balticporter
# 25                    American Stout                americanstout
# 26  American Double / Imperial Stout  americandoubleimperialstout
# 27                     Oatmeal Stout                 oatmealstout
# 28                Milk / Sweet Stout               milksweetstout
# 29                   Irish Dry Stout                irishdrystout
# 30                  Belgian Pale Ale               belgianpaleale
# 31                            Dubbel                       dubbel
# 32                            Tripel                       tripel
# 33                  Quadrupel (Quad)                quadrupelquad
# 34           Belgian Strong Dark Ale         belgianstrongdarkale
# 35            Saison / Farmhouse Ale           saisonfarmhouseale
# 36           American Pale Wheat Ale         americanpalewheatale
# 37                           Witbier                      witbier
# 38                Berliner Weissbier            berlinerweissbier
# 39                      Dunkelweizen                 dunkelweizen
# 40                        Hefeweizen                   hefeweizen
# 41                 American Wild Ale              americanwildale
# 42                    Lambic - Fruit                  lambicfruit
# 43                  Flanders Red Ale               flandersredale
# 44                            Gueuze                       gueuze
# 45                       Pumpkin Ale                   pumpkinale
# 46                          Rye Beer                      ryebeer
# 47                       Smoked Beer                   smokedbeer

# %%
def match_styles(username):
    #create df of user ratings
    user_ratings_df = user_ratings(username)
    print(len(user_ratings_df))
    # import or query for styles_df
    beer_features_df = pd.read_csv("../encoded1.csv")
    user_ratings_df = user_ratings_df.merge(beer_features_df, left_on = 'beer_link', right_on = 'URL', how = "right")
    rec_df = user_ratings_df[user_ratings_df['beer_link'].isnull()]
    user_df = user_ratings_df[user_ratings_df['beer_link'].notnull()]
    return rec_df, user_df

# %%
red_df, user_df = match_styles('cpmitchno1')
# Out:
# https://www.beeradvocate.com/user/beers/?start=0&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=50&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=100&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=150&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=200&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=250&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=300&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=350&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=400&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=450&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=500&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=550&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=600&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=650&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=700&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=750&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=800&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=850&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=900&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=950&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1000&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1050&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1100&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1150&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1200&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1250&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1300&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1350&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1400&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1450&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1500&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1550&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1600&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1650&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1700&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1750&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1800&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1850&ba=cpmitchno1&order=dateD&view=R
# https://www.beeradvocate.com/user/beers/?start=1900&ba=cpmitchno1&order=dateD&view=R
# 1880

# %%
len(user_df)
# Out:
# 568

# %%
len(red_df)
# Out:
# 20678

# %%
test = user_ratings_df.merge(beer_features, left_on = 'beer_link', right_on = 'URL', how = "right")

# %%
len(test)
# Out:
# 21246

# %%
recList = test[test['beer_link'].isnull()]
len(recList)
# Out:
# 20539

# %%
user_match = test[test['beer_link'].notnull()]
len(user_match)
# Out:
# 707

# %%
user_df.to_csv('../cpmitchno1match.csv', index = False)

# %%
red_df.to_csv('../cpmitchno1recs.csv', index = False)

# %%
user_match.sort_values('user_rating', ascending = False, inplace=True)
top = user_match.head(35)
# Out:
# /Users/ronessaacquesta/anaconda/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.to_csv('brutaltruthsbeers.csv')

# %%
top
# Out:
#                                              beer_link  rDev user_rating  \
# 633  https://www.beeradvocate.com/beer/profile/30/6...  16.2        4.74
# 596  https://www.beeradvocate.com/beer/profile/2430...  10.5        4.63
# 602  https://www.beeradvocate.com/beer/profile/63/3...   2.9         4.6
# 417  https://www.beeradvocate.com/beer/profile/3035...   2.0        4.59
# 704  https://www.beeradvocate.com/beer/profile/2430...  10.1        4.59
# 3    https://www.beeradvocate.com/beer/profile/1432...   2.7        4.59
# 17   https://www.beeradvocate.com/beer/profile/1798...     0        4.58
# 87   https://www.beeradvocate.com/beer/profile/208/...   5.6        4.54
# 310  https://www.beeradvocate.com/beer/profile/392/...   4.4        4.53
# 506  https://www.beeradvocate.com/beer/profile/259/...   1.1        4.51
# 705  https://www.beeradvocate.com/beer/profile/3199...  14.2         4.5
# 507  https://www.beeradvocate.com/beer/profile/1141...   2.0         4.5
# 670  https://www.beeradvocate.com/beer/profile/826/...   8.2         4.5
# 625  https://www.beeradvocate.com/beer/profile/48/7...   8.5        4.49
# 649  https://www.beeradvocate.com/beer/profile/1199...   0.4        4.49
# 146  https://www.beeradvocate.com/beer/profile/396/...   0.2        4.49
# 1    https://www.beeradvocate.com/beer/profile/1432...   3.5        4.49
# 258  https://www.beeradvocate.com/beer/profile/1199...   4.0        4.46
# 701  https://www.beeradvocate.com/beer/profile/2959...   5.7        4.45
# 555  https://www.beeradvocate.com/beer/profile/42/5...   8.3        4.43
# 471  https://www.beeradvocate.com/beer/profile/1037...   8.3        4.43
# 66   https://www.beeradvocate.com/beer/profile/147/...   7.5        4.43
# 404  https://www.beeradvocate.com/beer/profile/26/1...   2.8        4.42
# 31   https://www.beeradvocate.com/beer/profile/199/...   0.7        4.42
# 609  https://www.beeradvocate.com/beer/profile/147/...   1.6        4.41
# 74   https://www.beeradvocate.com/beer/profile/3521...   7.6         4.4
# 695  https://www.beeradvocate.com/beer/profile/1079...   6.0         4.4
# 4    https://www.beeradvocate.com/beer/profile/63/6...   2.1        4.35
# 530  https://www.beeradvocate.com/beer/profile/193/...   7.4        4.35
# 598  https://www.beeradvocate.com/beer/profile/1432...   3.6        4.35
# 207  https://www.beeradvocate.com/beer/profile/215/...   1.2        4.35
# 0    https://www.beeradvocate.com/beer/profile/429/...   4.8        4.35
# 73   https://www.beeradvocate.com/beer/profile/3104...   1.4        4.35
# 397  https://www.beeradvocate.com/beer/profile/2289...   0.5        4.35
# 59   https://www.beeradvocate.com/beer/profile/252/...   2.4        4.35
#
#       ABV          Availaility                                   Brewer  \
# 633  16.9                 Fall                    Avery Brewing Company
# 596  11.5             Rotating                        Evil Twin Brewing
# 602  12.2               Winter                        Deschutes Brewery
# 417  13.0             Rotating                     Prairie Artisan Ales
# 704  11.5             Rotating                        Evil Twin Brewing
# 3    11.0             Rotating                 Jackie O's Pub & Brewery
# 17    8.0             Rotating                  Lawson's Finest Liquids
# 87    9.5           Year-round                      Brouwerij Westmalle
# 310  12.7               Spring                  Weyerbacher Brewing Co.
# 506  10.0           Year-round               Brouwerij St. Bernardus NV
# 705   9.8               Winter                       Rhinegeist Brewery
# 507   9.5             Rotating                  Brasserie Dieu du Ciel!
# 670  10.5           Year-round        Brasserie de l'Abbaye du Val-Dieu
# 625  10.7           Year-round            Brouwerij Van Steenberge N.V.
# 649   8.3             Rotating                 Founders Brewing Company
# 146  12.0             Rotating                 AleSmith Brewing Company
# 1    11.0               Winter                 Jackie O's Pub & Brewery
# 258   9.0             Rotating                 Founders Brewing Company
# 701   6.7           Year-round                     JAFB Wooster Brewery
# 555  10.0             Rotating                         Brewery Ommegang
# 471   NaN             Rotating                 Barley's Brewing Company
# 66   13.0             Rotating                            Stone Brewing
# 404   7.7             Rotating                     3 Floyds Brewing Co.
# 31   10.0             Rotating            Ballast Point Brewing Company
# 609   8.1             Rotating                            Stone Brewing
# 74    9.0  Limited(brewedonce)         De Proefbrouwerij (bvba Andelot)
# 695  10.0             Rotating             Flying Monkeys Craft Brewery
# 4     6.4           Year-round                        Deschutes Brewery
# 530   5.8           Year-round          Anderson Valley Brewing Company
# 598   6.5             Rotating                 Jackie O's Pub & Brewery
# 207   9.0           Year-round                        BiÃ¨res de Chimay
# 0     9.8             Rotating                      Alaskan Brewing Co.
# 73    8.5             Rotating                      18th Street Brewery
# 397  11.8             Rotating                     Epic Brewing Company
# 59    5.3           Year-round  Bayerische Staatsbrauerei Weihenstephan
#
#      BrosScore                                          ImageLink  \
# 633       0.00    https://cdn.beeradvocate.com/im/beers/62449.jpg
# 596       0.00    https://cdn.beeradvocate.com/im/beers/90473.jpg
# 602       4.13    https://cdn.beeradvocate.com/im/beers/34420.jpg
# 417       0.00    https://cdn.beeradvocate.com/im/beers/94350.jpg
# 704       0.00    https://cdn.beeradvocate.com/im/beers/84140.jpg
# 3         4.25   https://cdn.beeradvocate.com/im/beers/132105.jpg
# 17        0.00   https://cdn.beeradvocate.com/im/beers/117177.jpg
# 4                        0                   0           1           0
# 530                      0                   0           0           1
# 598                      0                   0           0           1
# 207                      0                   0           0           0
# 0                        0                   0           0           0
# 73                       0                   0           0           1
# 397                      0                   0           0           1
# 59                       0                   0           1           0
#
#      Color_dark   Color_gold  Color_pale
# 633            0           0           0
# 596            1           0           0
# 602            0           0           0
# 417            0           0           0
# 704            1           0           0
# 3              1           0           0
# 17             0           0           0
# 87             0           1           0
# 310            0           0           0
# 506            0           0           0
# 705            1           0           0
# 507            0           0           0
# 670            0           0           0
# 625            0           0           0
# 649            0           0           0
# 146            0           0           0
# 1              1           0           0
# 258            1           0           0
# 701            0           0           0
# 555            1           0           0
# 471            1           0           0
# 66             0           0           0
# 404            0           0           0
# 31             1           0           0
# 609            0           0           0
# 74             1           0           0
# 695            0           0           0
# 4              0           0           0
# 530            0           0           0
# 598            0           0           0
# 207            1           0           0
# 0              1           0           0
# 73             0           0           0
# 397            0           0           0
# 59             0           0           0
#
# [35 rows x 49 columns]

# %%
a_list
# Out:
# [{'abv': '6.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/44865/222620/',
#   'beer_name': 'Rubriq-a-brac',
#   'beer_style': 'Bière de Garde',
#   'brewery': 'Whiner Beer Company',
#   'user_rating': '3.99'},
#  {'abv': '7.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/49024/323229/',
#   'beer_name': 'Swiss Chocolate Stout',
#   'beer_style': 'American Stout',
#   'brewery': 'March First Brewing',
#   'user_rating': '3.77'},
#  {'abv': '8.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/41951/185895/',
#   'beer_name': 'Wolf King Warrior',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Rusty Rail Brewing Company',
#   'user_rating': '3.84'},
#  {'abv': '9.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/30179/90824/',
#   'beer_name': 'Voltan',
#   'beer_style': 'Russian Imperial Stout',
#   'brewery': 'Hoof Hearted Brewing',
#   'user_rating': '3.78'},
#  {'abv': '9.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/25958/308986/',
#   'beer_name': 'Hammer',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Renegade Brewing Company',
#   'user_rating': '3.96'},
#  {'abv': '10.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33530/157207/',
#   'beer_name': 'Dire Wolf',
#   'beer_style': 'Russian Imperial Stout',
#   'brewery': "Wolf's Ridge Brewing",
#   'user_rating': '4.35'},
#  {'abv': '8.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/341/88275/',
#   'beer_name': 'Columbus Sohio Stout',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Columbus Brewing Company',
#   'user_rating': '4.35'},
#  {'abv': '?',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/287/42319/',
#   'beer_name': "Bell's Baltic Porter",
#   'beer_style': 'Baltic Porter',
#   'brewery': "Bell's Brewery, Inc.",
#   'user_rating': '4.04'},
#  {'abv': '11.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/39101/204686/',
#   'beer_name': 'Autumn Wind',
#   'beer_style': 'Russian Imperial Stout',
#   'brewery': 'Pigskin Brewing Company',
#   'user_rating': '3.92'},
#  {'abv': '12.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/199/50416/',
#   'beer_name': 'Barmy Golden Ale with Apricot & Honey',
#   'beer_style': 'American Strong Ale',
#   'brewery': 'Ballast Point Brewing Company',
#   'user_rating': '3.72'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/39101/321949/',
#   'beer_name': 'Highland Games Scottish Ale',
#   'beer_style': 'Scottish Ale',
#   'brewery': 'Pigskin Brewing Company',
#   'user_rating': '3.87'},
#  {'abv': '11.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/1432/132105/',
#   'beer_name': 'Bourbon Barrel Black Maple',
#   'beer_style': 'American Porter',
#   'brewery': "Jackie O's Pub & Brewery",
#   'user_rating': '4.59'},
#  {'abv': '6.40',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/63/60330/',
#   'beer_name': 'Fresh Squeezed IPA',
#   'beer_style': 'American IPA',
#   'brewery': 'Deschutes Brewery',
#   'user_rating': '4.35'},
#  {'abv': '7.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/35568/176925/',
#   'beer_name': 'Dead Blow - Coffee',
#   'beer_style': 'Foreign / Export Stout',
#   'brewery': 'Braxton Brewing Company',
#   'user_rating': '4.03'},
#  {'abv': '6.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/34783/153134/',
#   'beer_name': 'Dark Road Porter',
#   'beer_style': 'American Porter',
#   'brewery': 'Grand Junction Brewing Company',
#   'user_rating': '3.87'},
#  {'abv': '8.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/41/140/',
#   'beer_name': 'Corsendonk Christmas Ale',
#   'beer_style': 'Belgian Strong Dark Ale',
#   'brewery': 'Brouwerij Corsendonk',
#   'user_rating': '4.19'},
#  {'abv': '8.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/18539/52823/',
#   'beer_name': 'Danzig Baltic Porter',
#   'beer_style': 'Baltic Porter',
#   'brewery': 'Devils Backbone Brewing Company',
#   'user_rating': '4'},
#  {'abv': '4.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/345/271991/',
#   'beer_name': 'Home Grown New American Lager',
#   'beer_style': 'American Pale Lager',
#   'brewery': 'Victory Brewing Company - Downingtown',
#   'user_rating': '3.85'},
#  {'abv': '5.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/192/275731/',
#   'beer_name': 'Fat Tire Belgian White',
#   'beer_style': 'Witbier',
#   'brewery': 'New Belgium Brewing',
#   'user_rating': '3.69'},
#  {'abv': '14.10',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/63/303174/',
#   'beer_name': 'The Abyss (Rum Barrel-Aged)',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Deschutes Brewery',
#   'user_rating': '4.35'},
#  {'abv': '11.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/694/309422/',
#   'beer_name': 'The Mad Elf Grand Cru',
#   'beer_style': 'Belgian Strong Dark Ale',
#   'brewery': 'Tröegs Brewing Company',
#   'user_rating': '4.12'},
#  {'abv': '11.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/22893/298738/',
#   'beer_name': 'Triple Barrel Big Bad Baptist',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Epic Brewing Company',
#   'user_rating': '4.46'},
#  {'abv': '11.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/10272/303691/',
#   'beer_name': 'Vanishing Point 01',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Innis & Gunn',
#   'user_rating': '4.08'},
#  {'abv': '11.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/36487/315070/',
#   'beer_name': 'Panic Switch',
#   'beer_style': 'American Barleywine',
#   'brewery': 'Platform Beer Co.',
#   'user_rating': '4.02'},
#  {'abv': '10.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/31311/162299/',
#   'beer_name': 'Triporteur Full Moon 12 Belgian Oak Ale',
#   'beer_style': 'Belgian Strong Dark Ale',
#   'brewery': 'B.O.M. Brewery',
#   'user_rating': '4.1'},
#  {'abv': '7.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/4/10/',
#   'beer_name': 'Allagash Dubbel Ale',
#   'beer_style': 'Dubbel',
#   'brewery': 'Allagash Brewing Company',
#   'user_rating': '3.94'},
#  {'abv': '11.60',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/35568/286700/',
#   'beer_name': 'City Batch (Bourbon Barrel Aged Baltic Porter)',
#   'beer_style': 'Baltic Porter',
#   'brewery': 'Braxton Brewing Company',
#   'user_rating': '4.35'},
#  {'abv': '5.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/46778/264916/',
#   'beer_name': 'Hammer Session IPA',
#   'beer_style': 'American IPA',
#   'brewery': 'The Woodburn Brewery',
#   'user_rating': '4.02'},
#  {'abv': '9.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/1627/12051/',
#   'beer_name': "Raven's Eye Imperial Stout",
#   'beer_style': 'Russian Imperial Stout',
#   'brewery': 'Eel River Brewing Co.',
#   'user_rating': '4.19'},
#  {'abv': '11.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/22893/256182/',
#   'beer_name': 'Big Bad Baptista',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Epic Brewing Company',
#   'user_rating': '4.49'},
#  {'abv': '6.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/50839/309000/',
#   'beer_name': 'Jazz',
#   'beer_style': 'American Stout',
#   'brewery': 'Fretboard Brewing Company',
#   'user_rating': '3.77'},
#  {'abv': '9.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/46778/298909/',
#   'beer_name': 'Imperial Stout (Barrel Aged)',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'The Woodburn Brewery',
#   'user_rating': '4.35'},
#  {'abv': '10.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/38054/314961/',
#   'beer_name': 'Batch #016',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Nowhere In Particular Brewing',
#   'user_rating': '3.92'},
#  {'abv': '8.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33618/192432/',
#   'beer_name': 'Trappist Imperial Stout',
#   'beer_style': 'Russian Imperial Stout',
#   'brewery': 'The Spencer Brewery',
#   'user_rating': '3.96'},
#  {'abv': '12.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/199/302060/',
#   'beer_name': 'High West Barrel Aged Victory At Sea',
#   'beer_style': 'American Porter',
#   'brewery': 'Ballast Point Brewing Company',
#   'user_rating': '4.34'},
#  {'abv': '5.40',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/579/33183/',
#   'beer_name': 'Pipeline Porter',
#   'beer_style': 'American Porter',
#   'brewery': 'Kona Brewing Co.',
#   'user_rating': '3.77'},
#  {'abv': '4.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/15280/78023/',
#   'beer_name': 'Decadent Dark Chocolate Ale',
#   'beer_style': 'American Brown Ale',
#   'brewery': 'Atwater Brewery',
#   'user_rating': '3.63'},
#  {'abv': '4.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/4/237285/',
#   'beer_name': 'Allagash Hoppy Table Beer',
#   'beer_style': 'Belgian Pale Ale',
#   'brewery': 'Allagash Brewing Company',
#   'user_rating': '4.1'},
#  {'abv': '6.40',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/22512/303723/',
#   'beer_name': 'von Trapp Hoppy Märzen',
#   'beer_style': 'Märzen / Oktoberfest',
#   'brewery': 'von Trapp Brewing',
#   'user_rating': '4'},
#  {'abv': '8.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/700/14383/',
#   'beer_name': 'BiFrost',
#   'beer_style': 'Winter Warmer',
#   'brewery': 'Elysian Brewing Company',
#   'user_rating': '3.71'},
#  {'abv': '3.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/37303/167317/',
#   'beer_name': 'Party Guy',
#   'beer_style': 'American Wild Ale',
#   'brewery': 'Hermit Thrush Brewery',
#   'user_rating': '3.85'},
#  {'abv': '8.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/17980/117177/',
#   'beer_name': 'Sip Of Sunshine IPA',
#   'beer_style': 'American Double / Imperial IPA',
#   'brewery': "Lawson's Finest Liquids",
#   'user_rating': '4.58'},
#  {'abv': '10.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/34018/214679/',
#   'beer_name': "Nuttn' 2it (coffee)",
#   'beer_style': 'American Brown Ale',
#   'brewery': 'Zaftig Brewing Co.',
#   'user_rating': '4.3'},
#  {'abv': '12.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/5062/267881/',
#   'beer_name': 'Thomas Hardy - The Historical Ale',
#   'beer_style': 'English Barleywine',
#   'brewery': 'Meantime Brewing Company Limited',
#   'user_rating': '4.59'},
#  {'abv': '7.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/26/257312/',
#   'beer_name': 'Necron 99',
#   'beer_style': 'American IPA',
#   'brewery': '3 Floyds Brewing Co.',
#   'user_rating': '4.1'},
#  {'abv': '6.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/2171/6218/',
#   'beer_name': 'Kilt Lifter Scottish Style Ale',
#   'beer_style': 'Scottish Ale',
#   'brewery': 'Four Peaks Brewing Company - 8th Street Brewery',
#   'user_rating': '3.75'},
#  {'abv': '8.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33939/310622/',
#   'beer_name': 'Esther’s Lil Secret (2017)',
#   'beer_style': 'Winter Warmer',
#   'brewery': 'Warped Wing Brewing Company',
#   'user_rating': '4.06'},
#  {'abv': '8.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/31995/241790/',
#   'beer_name': 'Wee Willy',
#   'beer_style': 'Scotch Ale / Wee Heavy',
#   'brewery': 'Rhinegeist Brewery',
#   'user_rating': '4.19'},
#  {'abv': '4.90',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/2171/6815/',
#   'beer_name': '8th Street Pale Ale',
#   'beer_style': 'English Pale Ale',
#   'brewery': 'Four Peaks Brewing Company - 8th Street Brewery',
#   'user_rating': '3.52'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/49024/279505/',
#   'beer_name': 'Baltic Porter',
#   'beer_style': 'Baltic Porter',
#   'brewery': 'March First Brewing',
#   'user_rating': '3.73'},
#  {'abv': '6.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/192/197183/',
#   'beer_name': 'Citradelic Tangerine IPA',
#   'beer_style': 'American IPA',
#   'brewery': 'New Belgium Brewing',
#   'user_rating': '3.96'},
#  {'abv': '10.40',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/30/275489/',
#   'beer_name': 'Coconut Porter',
#   'beer_style': 'American Porter',
#   'brewery': 'Avery Brewing Company',
#   'user_rating': '4.16'},
#  {'abv': '9.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/36487/198838/',
#   'beer_name': 'Esther',
#   'beer_style': 'Belgian Strong Dark Ale',
#   'brewery': 'Platform Beer Co.',
#   'user_rating': '4'},
#  {'abv': '7.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/634/154156/',
#   'beer_name': 'Hommelbier Nieuwe Oogst Fresh Harvest 2014',
#   'beer_style': 'Saison / Farmhouse Ale',
#   'brewery': 'Leroy Breweries',
#   'user_rating': '4.09'},
#  {'abv': '?',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/8269/14633/',
#   'beer_name': 'Vanilla Cream Ale',
#   'beer_style': 'Cream Ale',
#   'brewery': 'Blackhorse Pub & Brewery',
#   'user_rating': '3.44'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/804/142878/',
#   'beer_name': 'Stupid Silly Sour',
#   'beer_style': 'Lambic - Unblended',
#   'brewery': 'Brasserie de Silly S.A.',
#   'user_rating': '3.85'},
#  {'abv': '8.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/430/122075/',
#   'beer_name': 'Peach Barrel Wheat Ale',
#   'beer_style': 'American Strong Ale',
#   'brewery': "Alltech's Lexington Brewing and Distilling Co.",
#   'user_rating': '3.75'},
#  {'abv': '7.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/1471/6903/',
#   'beer_name': 'Dark Horse Too Cream Stout',
#   'beer_style': 'Milk / Sweet Stout',
#   'brewery': 'Dark Horse Brewing Company',
#   'user_rating': '4'},
#  {'abv': '4.40',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/1/429/',
#   'beer_name': 'Pilsner Urquell',
#   'beer_style': 'Czech Pilsener',
#   'brewery': 'Plzeňský Prazdroj',
#   'user_rating': '3.69'},
#  {'abv': '5.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/9020/21688/',
#   'beer_name': 'Sly Rye Porter',
#   'beer_style': 'English Porter',
#   'brewery': 'Yazoo Brewing Company',
#   'user_rating': '3.92'},
#  {'abv': '3.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/9020/20893/',
#   'beer_name': 'Dos Perros',
#   'beer_style': 'American Brown Ale',
#   'brewery': 'Yazoo Brewing Company',
#   'user_rating': '3.73'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/36487/309215/',
#   'beer_name': 'Cocoa Suave',
#   'beer_style': 'Milk / Sweet Stout',
#   'brewery': 'Platform Beer Co.',
#   'user_rating': '3.96'},
#  {'abv': '8.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/898/312057/',
#   'beer_name': 'Heavy Seas / MadTree Partner Ships Wee Heavy',
#   'beer_style': 'Scotch Ale / Wee Heavy',
#   'brewery': 'Heavy Seas Beer',
#   'user_rating': '4.16'},
#  {'abv': '7.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/423/3322/',
#   'beer_name': 'Nutcracker Winter Warmer Ale',
#   'beer_style': 'Winter Warmer',
#   'brewery': 'Boulevard Brewing Co.',
#   'user_rating': '3.77'},
#  {'abv': '9.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/46778/244561/',
#   'beer_name': 'Chocolate Cherry Stout',
#   'beer_style': 'American Stout',
#   'brewery': 'The Woodburn Brewery',
#   'user_rating': '4.19'},
#  {'abv': '7.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/345/303464/',
#   'beer_name': 'Blackboard Series #7 - Black Forest Cake Stout with Cherry',
#   'beer_style': 'American Stout',
#   'brewery': 'Victory Brewing Company - Downingtown',
#   'user_rating': '3.53'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/45/570/',
#   'beer_name': 'Brooklyn Oktoberfest',
#   'beer_style': 'Märzen / Oktoberfest',
#   'brewery': 'Brooklyn Brewery',
#   'user_rating': '3.56'},
#  {'abv': '5.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/31724/106494/',
#   'beer_name': 'Strongman Coffee Milk Stout',
#   'beer_style': 'Milk / Sweet Stout',
#   'brewery': 'Hi-Wire Brewing',
#   'user_rating': '4.1'},
#  {'abv': '5.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/21092/309505/',
#   'beer_name': 'Iron Line Coal Pusher',
#   'beer_style': 'American Porter',
#   'brewery': 'World Brews',
#   'user_rating': '3.69'},
#  {'abv': '10.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/199/48505/',
#   'beer_name': 'Victory At Sea Imperial Porter with Coffee & Vanilla',
#   'beer_style': 'American Porter',
#   'brewery': 'Ballast Point Brewing Company',
#   'user_rating': '4.42'},
#  {'abv': '8.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/32481/129768/',
#   'beer_name': 'Fink (red Rye)',
#   'beer_style': 'Rye Beer',
#   'brewery': 'Bad Tom Smith Brewing',
#   'user_rating': '4.1'},
#  {'abv': '9.40',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/1432/88605/',
#   'beer_name': 'Bourbon Barrel-Aged Skipping Stone',
#   'beer_style': 'Quadrupel (Quad)',
#   'brewery': "Jackie O's Pub & Brewery",
#   'user_rating': '4.32'},
#  {'abv': '4.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/418/272894/',
#   'beer_name': 'Travelin’ Light',
#   'beer_style': 'Kölsch',
#   'brewery': 'Left Hand Brewing Company',
#   'user_rating': '3.74'},
#  {'abv': '5.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/10991/310262/',
#   'beer_name': 'Space Time',
#   'beer_style': 'Hefeweizen',
#   'brewery': 'Christian Moerlein Brewing Company',
#   'user_rating': '3.72'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/21092/309504/',
#   'beer_name': 'Iron Line Midtown Station',
#   'beer_style': 'American Amber / Red Ale',
#   'brewery': 'World Brews',
#   'user_rating': '3.44'},
#  {'abv': '7.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/68/112953/',
#   'beer_name': 'Fever Dream Mango Habanero IPA',
#   'beer_style': 'American IPA',
#   'brewery': 'Flying Dog Brewery',
#   'user_rating': '3.77'},
#  {'abv': '5.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/429/49070/',
#   'beer_name': 'Alaskan White',
#   'beer_style': 'Witbier',
#   'brewery': 'Alaskan Brewing Co.',
#   'user_rating': '3.12'},
#  {'abv': '12.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/1432/187700/',
#   'beer_name': 'Bourbon Barrel Champion Ground',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': "Jackie O's Pub & Brewery",
#   'user_rating': '4.49'},
#  {'abv': '12.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/345/8998/',
#   'beer_name': 'V-Twelve',
#   'beer_style': 'Quadrupel (Quad)',
#   'brewery': 'Victory Brewing Company - Downingtown',
#   'user_rating': '4.19'},
#  {'abv': '4.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/192/246993/',
#   'beer_name': 'Tartastic Lemon Ginger Sour',
#   'beer_style': 'American Wild Ale',
#   'brewery': 'New Belgium Brewing',
#   'user_rating': '3.46'},
#  {'abv': '12.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/1432/301855/',
#   'beer_name': 'Black Mask',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': "Jackie O's Pub & Brewery",
#   'user_rating': '4.34'},
#  {'abv': '8.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/41240/308668/',
#   'beer_name': 'Truck Wreck',
#   'beer_style': 'Doppelbock',
#   'brewery': "Devil's Kettle Brewing",
#   'user_rating': '3.78'},
#  {'abv': '10.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/41240/308510/',
#   'beer_name': 'MOA Beer',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': "Devil's Kettle Brewing",
#   'user_rating': '3.87'},
#  {'abv': '7.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/41240/181684/',
#   'beer_name': 'Spider Silk',
#   'beer_style': 'American Blonde Ale',
#   'brewery': "Devil's Kettle Brewing",
#   'user_rating': '3.85'},
#  {'abv': '6.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/41563/308494/',
#   'beer_name': 'And Now For Something Completely Different',
#   'beer_style': 'Saison / Farmhouse Ale',
#   'brewery': 'Little Fish Brewing Company',
#   'user_rating': '3.9'},
#  {'abv': '7.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/18076/83634/',
#   'beer_name': 'Cervesa Del Montseny HivernAle',
#   'beer_style': 'Winter Warmer',
#   'brewery': 'Companyia Cervesera del Montseny',
#   'user_rating': '3.94'},
#  {'abv': '7.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/158/47440/',
#   'beer_name': 'Claymore Scotch Ale',
#   'beer_style': 'Scotch Ale / Wee Heavy',
#   'brewery': 'Great Divide Brewing Company',
#   'user_rating': '3.93'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/10991/289901/',
#   'beer_name': 'Mexican Style Lime Lager',
#   'beer_style': 'Fruit / Vegetable Beer',
#   'brewery': 'Christian Moerlein Brewing Company',
#   'user_rating': '2.92'},
#  {'abv': '5.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/40751/307641/',
#   'beer_name': 'Marzen Oktoberfest',
#   'beer_style': 'Märzen / Oktoberfest',
#   'brewery': 'Moeller Brew Barn',
#   'user_rating': '3.52'},
#  {'abv': '5.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/192/607/',
#   'beer_name': 'Fat Tire Amber Ale',
#   'beer_style': 'American Amber / Red Ale',
#   'brewery': 'New Belgium Brewing',
#   'user_rating': '3.69'},
#  {'abv': '11.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/3912/272200/',
#   'beer_name': 'Where The Buffalo Roam',
#   'beer_style': 'American Barleywine',
#   'brewery': "Cameron's Brewing Co.",
#   'user_rating': '4.12'},
#  {'abv': '8.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/113/46749/',
#   'beer_name': "Samuel Smith's Yorkshire Stingo",
#   'beer_style': 'English Strong Ale',
#   'brewery': 'Samuel Smith Old Brewery (Tadcaster)',
#   'user_rating': '4.1'},
#  {'abv': '5.40',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/30182/173240/',
#   'beer_name': 'Norden Hoch Oktoberfest',
#   'beer_style': 'Märzen / Oktoberfest',
#   'brewery': 'North High Brewing Company',
#   'user_rating': '3.79'},
#  {'abv': '13.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/30356/235533/',
#   'beer_name': 'Paradise',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Prairie Artisan Ales',
#   'user_rating': '4.31'},
#  {'abv': '11.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/396/225405/',
#   'beer_name': 'Private Stock Ale',
#   'beer_style': 'Old Ale',
#   'brewery': 'AleSmith Brewing Company',
#   'user_rating': '4.34'},
#  {'abv': '10.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/345/219146/',
#   'beer_name': 'Tart Ten',
#   'beer_style': 'American Wild Ale',
#   'brewery': 'Victory Brewing Company - Downingtown',
#   'user_rating': '3.93'},
#  {'abv': '?',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/1464/58623/',
#   'beer_name': 'Elevator Mocha Plum Stout',
#   'beer_style': 'American Stout',
#   'brewery': 'Elevator Brewery & Draught Haus',
#   'user_rating': '4.15'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/423/274102/',
#   'beer_name': 'Tough Kitty',
#   'beer_style': 'Milk / Sweet Stout',
#   'brewery': 'Boulevard Brewing Co.',
#   'user_rating': '4'},
#  {'abv': '6.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/36487/264994/',
#   'beer_name': 'High Brow Barista Coffee Rye Pale Ale',
#   'beer_style': 'American Pale Ale (APA)',
#   'brewery': 'Platform Beer Co.',
#   'user_rating': '3.94'},
#  {'abv': '5.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/287/1924/',
#   'beer_name': "Bell's Best Brown",
#   'beer_style': 'American Brown Ale',
#   'brewery': "Bell's Brewery, Inc.",
#   'user_rating': '3.86'},
#  {'abv': '11.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/423/204164/',
#   'beer_name': 'Whiskey Barrel Stout',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Boulevard Brewing Co.',
#   'user_rating': '4.15'},
#  {'abv': '8.90',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/29068/306413/',
#   'beer_name': 'Beast of Tadmor Village',
#   'beer_style': 'Doppelbock',
#   'brewery': 'The Dayton Beer Company',
#   'user_rating': '3.89'},
#  {'abv': '6.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/31093/306299/',
#   'beer_name': 'Scotchy McScotchface',
#   'beer_style': 'Herbed / Spiced Beer',
#   'brewery': 'MadTree Brewing',
#   'user_rating': '3.77'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/29858/306269/',
#   'beer_name': "Backpacker's Breakfast",
#   'beer_style': 'Oatmeal Stout',
#   'brewery': 'Fifty West Brewing Co',
#   'user_rating': '4.08'},
#  {'abv': '7.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/46778/306089/',
#   'beer_name': 'Superfly',
#   'beer_style': 'American Amber / Red Ale',
#   'brewery': 'The Woodburn Brewery',
#   'user_rating': '4.21'},
#  {'abv': '13.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/46778/275217/',
#   'beer_name': 'English Barleywine',
#   'beer_style': 'English Barleywine',
#   'brewery': 'The Woodburn Brewery',
#   'user_rating': '4.35'},
#  {'abv': '5.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/46778/305945/',
#   'beer_name': 'Scottish Export Ale',
#   'beer_style': 'Scottish Ale',
#   'brewery': 'The Woodburn Brewery',
#   'user_rating': '4.04'},
#  {'abv': '9.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/16866/234214/',
#   'beer_name': 'Terreux Quadrupel Tonnellerie',
#   'beer_style': 'Quadrupel (Quad)',
#   'brewery': 'The Bruery',
#   'user_rating': '3.96'},
#  {'abv': '8.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33530/158836/',
#   'beer_name': 'Sustinator',
#   'beer_style': 'Doppelbock',
#   'brewery': "Wolf's Ridge Brewing",
#   'user_rating': '4'},
#  {'abv': '5.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/44537/302218/',
#   'beer_name': 'Oakd',
#   'beer_style': 'Märzen / Oktoberfest',
#   'brewery': 'Sibling Revelry Brewing',
#   'user_rating': '3.98'},
#  {'abv': '10.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/664/12873/',
#   'beer_name': 'Courage Imperial Russian Stout',
#   'beer_style': 'Russian Imperial Stout',
#   'brewery': "Wells & Young's Ltd",
#   'user_rating': '4.34'},
#  {'abv': '5.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33530/149660/',
#   'beer_name': 'Gold Standard',
#   'beer_style': 'Munich Helles Lager',
#   'brewery': "Wolf's Ridge Brewing",
#   'user_rating': '3.69'},
#  {'abv': '6.40',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/32953/152985/',
#   'beer_name': 'Opossum Run Pale Ale',
#   'beer_style': 'American Pale Ale (APA)',
#   'brewery': 'Millersburg Brewing Company',
#   'user_rating': '3.77'},
#  {'abv': '5.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/42493/230022/',
#   'beer_name': 'Pendragon',
#   'beer_style': 'Herbed / Spiced Beer',
#   'brewery': 'Royal Docks Brewing Company',
#   'user_rating': '3.6'},
#  {'abv': '10.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/38623/305492/',
#   'beer_name': 'Supernova',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Dogberry Brewing',
#   'user_rating': '4.04'},
#  {'abv': '5.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/912/2910/',
#   'beer_name': 'Presidente',
#   'beer_style': 'American Adjunct Lager',
#   'brewery': 'Cervecería Nacional Dominicana',
#   'user_rating': '2.68'},
#  {'abv': '8.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/38623/305360/',
#   'beer_name': 'Husky',
#   'beer_style': 'American Porter',
#   'brewery': 'Dogberry Brewing',
#   'user_rating': '3.92'},
#  {'abv': '6.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33530/279212/',
#   'beer_name': 'Night Method',
#   'beer_style': 'Milk / Sweet Stout',
#   'brewery': "Wolf's Ridge Brewing",
#   'user_rating': '4.42'},
#  {'abv': '4.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/192/262695/',
#   'beer_name': 'Dayblazer',
#   'beer_style': 'American Blonde Ale',
#   'brewery': 'New Belgium Brewing',
#   'user_rating': '3.31'},
#  {'abv': '6.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/25957/229403/',
#   'beer_name': 'Prosperity Wheat',
#   'beer_style': 'Hefeweizen',
#   'brewery': 'Market Garden Brewery',
#   'user_rating': '3.99'},
#  {'abv': '5.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/341/245216/',
#   'beer_name': 'Thunderlips',
#   'beer_style': 'American Pale Ale (APA)',
#   'brewery': 'Columbus Brewing Company',
#   'user_rating': '4'},
#  {'abv': '6.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/39101/304806/',
#   'beer_name': 'Golden Bear',
#   'beer_style': 'Saison / Farmhouse Ale',
#   'brewery': 'Pigskin Brewing Company',
#   'user_rating': '3.94'},
#  {'abv': '5.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/44537/279625/',
#   'beer_name': "Rowan's American Red",
#   'beer_style': 'Irish Red Ale',
#   'brewery': 'Sibling Revelry Brewing',
#   'user_rating': '3.47'},
#  {'abv': '7.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33530/237074/',
#   'beer_name': "L'Abondance",
#   'beer_style': 'Saison / Farmhouse Ale',
#   'brewery': "Wolf's Ridge Brewing",
#   'user_rating': '4.09'},
#  {'abv': '5.80',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/124/386/',
#   'beer_name': 'Paulaner Oktoberfest Bier',
#   'beer_style': 'Märzen / Oktoberfest',
#   'brewery': 'Paulaner Brauerei GmbH & Co. KG',
#   'user_rating': '3.78'},
#  {'abv': '7.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33530/230141/',
#   'beer_name': 'Heretical IPA',
#   'beer_style': 'Belgian IPA',
#   'brewery': "Wolf's Ridge Brewing",
#   'user_rating': '4'},
#  {'abv': '13.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/392/276332/',
#   'beer_name': 'Finally Legal',
#   'beer_style': 'American Double / Imperial Stout',
#   'brewery': 'Weyerbacher Brewing Co.',
#   'user_rating': '4.34'},
#  {'abv': '5.60',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/29599/304133/',
#   'beer_name': 'Dunkelweizen',
#   'beer_style': 'Dunkelweizen',
#   'brewery': 'JAFB Wooster Brewery',
#   'user_rating': '3.93'},
#  {'abv': '8.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/5850/41463/',
#   'beer_name': 'Riegele Augustus Weizendoppelbock',
#   'beer_style': 'Weizenbock',
#   'brewery': 'Brauhaus Riegele',
#   'user_rating': '4.19'},
#  {'abv': '12.12',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/13307/59869/',
#   'beer_name': 'George',
#   'beer_style': 'Russian Imperial Stout',
#   'brewery': 'Mikkeller ApS',
#   'user_rating': '4.25'},
#  {'abv': '5.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/37742/152991/',
#   'beer_name': 'Code 3',
#   'beer_style': 'American Amber / Red Ale',
#   'brewery': 'Old Firehouse Brewing',
#   'user_rating': '3.61'},
#  {'abv': '5.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/37742/152990/',
#   'beer_name': 'Pin-Up Girl',
#   'beer_style': 'American Blonde Ale',
#   'brewery': 'Old Firehouse Brewing',
#   'user_rating': '3.47'},
#  {'abv': '7.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/35568/302830/',
#   'beer_name': "Graeter's Blueberry Pie Brown Ale",
#   'beer_style': 'American Brown Ale',
#   'brewery': 'Braxton Brewing Company',
#   'user_rating': '3.96'},
#  {'abv': '7.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/13371/31551/',
#   'beer_name': "Wynona's Big Brown Ale",
#   'beer_style': 'American Brown Ale',
#   'brewery': 'Voodoo Brewery',
#   'user_rating': '3.85'},
#  {'abv': '6.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/287/58981/',
#   'beer_name': "Bell's Quinannan Falls Special Lager Beer",
#   'beer_style': 'American Pale Lager',
#   'brewery': "Bell's Brewery, Inc.",
#   'user_rating': '4.02'},
#  {'abv': '8.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/209/10848/',
#   'beer_name': 'Guinness Special Export Stout / Antwerpen Stout',
#   'beer_style': 'Foreign / Export Stout',
#   'brewery': 'Guinness Ltd.',
#   'user_rating': '4.18'},
#  {'abv': '4.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33618/229201/',
#   'beer_name': 'Spencer Trappist Feierabendbier',
#   'beer_style': 'German Pilsener',
#   'brewery': 'The Spencer Brewery',
#   'user_rating': '3.54'},
#  {'abv': '9.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/13371/31546/',
#   'beer_name': 'Voodoo Love Child',
#   'beer_style': 'Tripel',
#   'brewery': 'Voodoo Brewery',
#   'user_rating': '3.85'},
#  {'abv': '10.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/31093/114276/',
#   'beer_name': 'Axis Mundi',
#   'beer_style': 'Russian Imperial Stout',
#   'brewery': 'MadTree Brewing',
#   'user_rating': '4.37'},
#  {'abv': '10.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/287/1891/',
#   'beer_name': 'Third Coast Old Ale',
#   'beer_style': 'American Barleywine',
#   'brewery': "Bell's Brewery, Inc.",
#   'user_rating': '4.18'},
#  {'abv': '5.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/1146/160129/',
#   'beer_name': 'Fulton & Wood My Shout',
#   'beer_style': 'American Pale Ale (APA)',
#   'brewery': 'Goose Island Beer Co.',
#   'user_rating': '3.92'},
#  {'abv': '6.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/132/51071/',
#   'beer_name': "Captain Sig's Northwestern Ale",
#   'beer_style': 'American Amber / Red Ale',
#   'brewery': 'Rogue Ales',
#   'user_rating': '3.92'},
#  {'abv': '7.50',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/41563/301153/',
#   'beer_name': 'Sukha',
#   'beer_style': 'Oatmeal Stout',
#   'brewery': 'Little Fish Brewing Company',
#   'user_rating': '3.92'},
#  {'abv': '9.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/33939/301146/',
#   'beer_name': 'Pirogue Blanc',
#   'beer_style': 'Tripel',
#   'brewery': 'Warped Wing Brewing Company',
#   'user_rating': '4'},
#  {'abv': '9.20',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/13371/31545/',
#   'beer_name': 'Gran Met',
#   'beer_style': 'Tripel',
#   'brewery': 'Voodoo Brewery',
#   'user_rating': '3.75'},
#  {'abv': '13.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/26850/290478/',
#   'beer_name': "Pretty Willie's Imperial Stout",
#   'beer_style': 'Russian Imperial Stout',
#   'brewery': 'Against The Grain Brewery & Smokehouse',
#   'user_rating': '4.35'},
#  {'abv': '5.70',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/19544/294855/',
#   'beer_name': "G'Suffa!",
#   'beer_style': 'Märzen / Oktoberfest',
#   'brewery': "Fat Head's Brewery & Saloon",
#   'user_rating': '3.93'},
#  {'abv': '4.90',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/31995/158602/',
#   'beer_name': 'Steve',
#   'beer_style': 'American Brown Ale',
#   'brewery': 'Rhinegeist Brewery',
#   'user_rating': '3.92'},
#  {'abv': '5.30',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/252/808/',
#   'beer_name': 'Weihenstephaner Hefeweissbier Dunkel',
#   'beer_style': 'Dunkelweizen',
#   'brewery': 'Bayerische Staatsbrauerei Weihenstephan',
#   'user_rating': '4.35'},
#  {'abv': '5.00',
#   'beer_link': 'https://www.beeradvocate.com/beer/profile/140/3558/',
#   'beer_name': 'Sierra Nevada Summerfest',
#   'beer_style': 'Czech Pilsener',
#   'brewery': 'Sierra Nevada Brewing Co.',
#   'user_rating': '3.79'}]

# %%
username = 'brutaltruth'
ratings_count = 0 
url = f"https://www.beeradvocate.com/user/beers/?start={ratings_count}&ba={username}&order=dateD&view=R"

html = requests.get(url)


#     html = browser.html
 # Parse HTML with Beautiful Soup
soup = BeautifulSoup(html.text, 'html.parser')
results = soup.find_all('table')
    # results
   
    # Click the 'Next' button on each page
   # browser.click_link_by_partial_text('next')

# %%
a_list = results[0].find_all('a')
del a_list[:11]
del a_list[-4:]
a_list
# Out:
# [<a href="/beer/profile/44865/222620/?ba=Brutaltruth#review"><b>Rubriq-a-brac</b></a>,
#  <a href="/beer/profile/44865/">Whiner Beer Company</a>,
#  <a href="/beer/style/127/">Bière de Garde</a>,
#  <a href="/beer/profile/49024/323229/?ba=Brutaltruth#review"><b>Swiss Chocolate Stout</b></a>,
#  <a href="/beer/profile/49024/">March First Brewing</a>,
#  <a href="/beer/style/158/">American Stout</a>,
#  <a href="/beer/profile/41951/185895/?ba=Brutaltruth#review"><b>Wolf King Warrior</b></a>,
#  <a href="/beer/profile/41951/">Rusty Rail Brewing Company</a>,
#  <a href="/beer/style/157/">American Double / Imperial Stout</a>,
#  <a href="/beer/profile/30179/90824/?ba=Brutaltruth#review"><b>Voltan</b></a>,
#  <a href="/beer/profile/30179/">Hoof Hearted Brewing</a>,
#  <a href="/beer/style/84/">Russian Imperial Stout</a>,
#  <a href="/beer/profile/25958/308986/?ba=Brutaltruth#review"><b>Hammer</b></a>,
#  <a href="/beer/profile/25958/">Renegade Brewing Company</a>,
#  <a href="/beer/style/157/">American Double / Imperial Stout</a>,
#  <a href="/beer/profile/33530/157207/?ba=Brutaltruth#review"><b>Dire Wolf</b></a>,
#  <a href="/beer/profile/33530/">Wolf's Ridge Brewing</a>,
#  <a href="/beer/style/84/">Russian Imperial Stout</a>,
#  <a href="/beer/profile/341/88275/?ba=Brutaltruth#review"><b>Columbus Sohio Stout</b></a>,
#  <a href="/beer/profile/341/">Columbus Brewing Company</a>,
#  <a href="/beer/style/157/">American Double / Imperial Stout</a>,
#  <a href="/beer/profile/287/42319/?ba=Brutaltruth#review"><b>Bell's Baltic Porter</b></a>,
#  <a href="/beer/profile/287/">Bell's Brewery, Inc.</a>,
#  <a href="/beer/style/80/">Baltic Porter</a>,
#  <a href="/beer/profile/39101/204686/?ba=Brutaltruth#review"><b>Autumn Wind</b></a>,
#  <a href="/beer/profile/39101/">Pigskin Brewing Company</a>,
#  <a href="/beer/style/84/">Russian Imperial Stout</a>,
#  <a href="/beer/style/154/">English Pale Ale</a>,
#  <a href="/beer/profile/49024/279505/?ba=Brutaltruth#review"><b>Baltic Porter</b></a>,
#  <a href="/beer/profile/49024/">March First Brewing</a>,
#  <a href="/beer/style/80/">Baltic Porter</a>]

# %%
a_item_list=[]
for x in a_list:
    a_item=x.text
    a_item_list.append(a_item)
len(a_item_list)
# Out:
# 150

# %%
a_url_list=[]
for x in a_list:
    a_item=x['href']
    a_url_list.append(a_item)
a_url_list

beer_url_list=[]
for item in a_url_list[::3]:
    beer_url_list.append(item)
beer_url_list
# Out:
# ['/beer/profile/44865/222620/?ba=Brutaltruth#review',
#  '/beer/profile/49024/323229/?ba=Brutaltruth#review',
#  '/beer/profile/41951/185895/?ba=Brutaltruth#review',
#  '/beer/profile/30179/90824/?ba=Brutaltruth#review',
#  '/beer/profile/25958/308986/?ba=Brutaltruth#review',
#  '/beer/profile/33530/157207/?ba=Brutaltruth#review',
#  '/beer/profile/341/88275/?ba=Brutaltruth#review',
#  '/beer/profile/287/42319/?ba=Brutaltruth#review',
#  '/beer/profile/39101/204686/?ba=Brutaltruth#review',
#  '/beer/profile/199/50416/?ba=Brutaltruth#review',
#  '/beer/profile/39101/321949/?ba=Brutaltruth#review',
#  '/beer/profile/1432/132105/?ba=Brutaltruth#review',
#  '/beer/profile/63/60330/?ba=Brutaltruth#review',
#  '/beer/profile/35568/176925/?ba=Brutaltruth#review',
#  '/beer/profile/34783/153134/?ba=Brutaltruth#review',
#  '/beer/profile/41/140/?ba=Brutaltruth#review',
#  '/beer/profile/18539/52823/?ba=Brutaltruth#review',
#  '/beer/profile/345/271991/?ba=Brutaltruth#review',
#  '/beer/profile/192/275731/?ba=Brutaltruth#review',
#  '/beer/profile/63/303174/?ba=Brutaltruth#review',
#  '/beer/profile/694/309422/?ba=Brutaltruth#review',
#  '/beer/profile/22893/298738/?ba=Brutaltruth#review',
#  '/beer/profile/10272/303691/?ba=Brutaltruth#review',
#  '/beer/profile/36487/315070/?ba=Brutaltruth#review',
#  '/beer/profile/31311/162299/?ba=Brutaltruth#review',
#  '/beer/profile/4/10/?ba=Brutaltruth#review',
#  '/beer/profile/35568/286700/?ba=Brutaltruth#review',
#  '/beer/profile/46778/264916/?ba=Brutaltruth#review',
#  '/beer/profile/1627/12051/?ba=Brutaltruth#review',
#  '/beer/profile/22893/256182/?ba=Brutaltruth#review',
#  '/beer/profile/50839/309000/?ba=Brutaltruth#review',
#  '/beer/profile/46778/298909/?ba=Brutaltruth#review',
#  '/beer/profile/38054/314961/?ba=Brutaltruth#review',
#  '/beer/profile/33618/192432/?ba=Brutaltruth#review',
#  '/beer/profile/199/302060/?ba=Brutaltruth#review',
#  '/beer/profile/579/33183/?ba=Brutaltruth#review',
#  '/beer/profile/15280/78023/?ba=Brutaltruth#review',
#  '/beer/profile/4/237285/?ba=Brutaltruth#review',
#  '/beer/profile/22512/303723/?ba=Brutaltruth#review',
#  '/beer/profile/700/14383/?ba=Brutaltruth#review',
#  '/beer/profile/37303/167317/?ba=Brutaltruth#review',
#  '/beer/profile/17980/117177/?ba=Brutaltruth#review',
#  '/beer/profile/34018/214679/?ba=Brutaltruth#review',
#  '/beer/profile/5062/267881/?ba=Brutaltruth#review',
#  '/beer/profile/26/257312/?ba=Brutaltruth#review',
#  '/beer/profile/2171/6218/?ba=Brutaltruth#review',
#  '/beer/profile/33939/310622/?ba=Brutaltruth#review',
#  '/beer/profile/31995/241790/?ba=Brutaltruth#review',
#  '/beer/profile/2171/6815/?ba=Brutaltruth#review',
#  '/beer/profile/49024/279505/?ba=Brutaltruth#review']

# %%
for item in a_item_list[::3]:
    beer_name_list.append(item)
print(beer_name_list)


for item in a_item_list[1::3]:
    brewry_list.append(item)
#print(brewry_list)


for item in a_item_list[2::3]:
    beer_sty_list.append(item)
#print(beer_sty_list)
# Out:
# ['Rubriq-a-brac', 'Swiss Chocolate Stout', 'Wolf King Warrior', 'Voltan', 'Hammer', 'Dire Wolf', 'Columbus Sohio Stout', "Bell's Baltic Porter", 'Autumn Wind', 'Barmy Golden Ale with Apricot & Honey', 'Highland Games Scottish Ale', 'Bourbon Barrel Black Maple', 'Fresh Squeezed IPA', 'Dead Blow - Coffee', 'Dark Road Porter', 'Corsendonk Christmas Ale', 'Danzig Baltic Porter', 'Home Grown New American Lager', 'Fat Tire Belgian White', 'The Abyss (Rum Barrel-Aged)', 'The Mad Elf Grand Cru', 'Triple Barrel Big Bad Baptist', 'Vanishing Point 01', 'Panic Switch', 'Triporteur Full Moon 12 Belgian Oak Ale', 'Allagash Dubbel Ale', 'City Batch (Bourbon Barrel Aged Baltic Porter)', 'Hammer Session IPA', "Raven's Eye Imperial Stout", 'Big Bad Baptista', 'Jazz', 'Imperial Stout (Barrel Aged)', 'Batch #016', 'Trappist Imperial Stout', 'High West Barrel Aged Victory At Sea', 'Pipeline Porter', 'Decadent Dark Chocolate Ale', 'Allagash Hoppy Table Beer', 'von Trapp Hoppy Märzen', 'BiFrost', 'Party Guy', 'Sip Of Sunshine IPA', "Nuttn' 2it (coffee)", 'Thomas Hardy - The Historical Ale', 'Necron 99', 'Kilt Lifter Scottish Style Ale', 'Esther’s Lil Secret (2017)', 'Wee Willy', '8th Street Pale Ale', 'Baltic Porter']

# %%
# len(beer_name_list)
# len(brewry_list)
# len(beer_sty_list)

# %%
b_list = results[0].find_all('b')
del b_list[-1:]
del b_list[:1]
# b_list

b_item_list=[]
for item in b_list:
    b_item=item.text
    b_item_list.append(b_item)
len(b_item_list)
# Out:
# 100

# %%
beer_style_list=[]
rating_list=[]
for item in b_item_list[::2]:
    beer_style_list.append(item)    
# len(beer_style_list)

for item in b_item_list[1::2]:
    rating_list.append(item)
len(rating_list)
# Out:
# 50

# %%
# len(beer_style_list)
# len(rating_list)

# %%
df =pd.DataFrame({"beer_style": beer_style_list, 
                 "match_beer_style": beer_sty_list,
                 "review_url":beer_url_list,
                 "beer_name": beer_name_list,
                 "brewry_name": brewry_list,
                 "rating": rating_list})
df
# Out:
#                                          beer_name  \
# 0                                    Rubriq-a-brac
# 1                            Swiss Chocolate Stout
# 36   /beer/profile/15280/78023/?ba=Brutaltruth#review
# 37      /beer/profile/4/237285/?ba=Brutaltruth#review
# 38  /beer/profile/22512/303723/?ba=Brutaltruth#review
# 39     /beer/profile/700/14383/?ba=Brutaltruth#review
# 40  /beer/profile/37303/167317/?ba=Brutaltruth#review
# 41  /beer/profile/17980/117177/?ba=Brutaltruth#review
# 42  /beer/profile/34018/214679/?ba=Brutaltruth#review
# 43   /beer/profile/5062/267881/?ba=Brutaltruth#review
# 44     /beer/profile/26/257312/?ba=Brutaltruth#review
# 45     /beer/profile/2171/6218/?ba=Brutaltruth#review
# 46  /beer/profile/33939/310622/?ba=Brutaltruth#review
# 47  /beer/profile/31995/241790/?ba=Brutaltruth#review
# 48     /beer/profile/2171/6815/?ba=Brutaltruth#review
# 49  /beer/profile/49024/279505/?ba=Brutaltruth#review

# %%
df.sort_values('rating', ascending = False)
len(df)*.2
# Out:
# 10.0

# %%
for x in b_list:
    ind_beers = re.sub(r'<b>', '', x)
    print(ind_beers)
    beer_dict = {"style_name": beer.text}
    all_styles.append(beer_dict)
all_style
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-d89288e07707> in <module>()
#       1 for x in b_list:
# ----> 2     ind_beers = re.sub(r'<b>', '', x)
#       3     print(ind_beers)
#       4     beer_dict = {"style_name": beer.text}
#       5     all_styles.append(beer_dict)
#
# /Users/Ronessa/anaconda/envs/PythonData/lib/python3.6/re.py in sub(pattern, repl, string, count, flags)
#     189     a callable, it's passed the match object and must return
#     190     a replacement string to be used."""
# --> 191     return _compile(pattern, flags).sub(repl, string, count)
#     192
#     193 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# list for all beer styles from beer advocate
all_styles = []
base_url = "https://www.beeradvocate.com"
# get a dict to hold style and link
for x in target_indexes:
    ind_beers = tds[x].find_all('a')
    print(ind_beers)
#     for beer in ind_beers:
#         beer_text = re.sub(r'\W+', '', beer.text.lower())
#         beer_dict = {"style_name": beer.text, "match_name": beer_text}
#         all_styles.append(beer_dict)

 # Iterate through each book
#  for beer in tds:
#      # Use Beautiful Soup's find() method to navigate and retrieve attributes
#      b = beer.find('b')
# #      link = td.find('a')
# #      href = link['href']
# #      b = link['b']
#      print('-----------')
#      print(b)
# #      print('http://books.toscrape.com/' + href)

# %%
# Iterate through all pages
for x in range(5):
    # beer advocate styles url
    url = "https://www.beeradvocate.com/user/beers/?ba=brutaltruth"

    # response from site
    response = requests.get(url)

    #create Beautiful soup object and parse
    soup = BeautifulSoup(response.text, 'html.parser')
    results = soup.find_all('table')

    # find all 'tds' in results, only index 0 holds correct table
    tds = results[0].find_all('td')
    tds
 
    
     # Iterate through each book
#      for beer in tds:
#          # Use Beautiful Soup's find() method to navigate and retrieve attributes
#          b = beer.find('b')
    #      link = td.find('a')
    #      href = link['href']
    #      b = link['b']
#          print('-----------')
#          print(b)
    #      print('http://books.toscrape.com/' + href)

# Click the 'Next' button on each page
# browser.click_link_by_partial_text('next')

# %%
import re
re.findall(r"([\d.]*\d+)", '+3.4%')
# Out:
# ['3.4']
